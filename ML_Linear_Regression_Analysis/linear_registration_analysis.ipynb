# %%
# Инициализация библиотек
import numpy as nm  # для работы с массивами и матрицами, а также выполнения математических операций.
import matplotlib.pyplot as plt  # для создания графиков и визуализации данных.
import pandas as pd  # для работы с данными, их очистки и анализа
import seaborn as sns  # для создания статистических графиков и улучшения визуализации данных.
# %matplotlib inline
# магическая команда Jupyter Notebook для отображения графиков непосредственно в блокноте

# %%
# Инициализация данных
companies = pd.read_csv('./1000_Companies.csv')  # загружает данные из файла CSV в DataFrame companies с использованием библиотеки pandas.
X = companies.iloc[:, :-1].values  # извлекает данные всех столбцов, кроме последнего, и сохраняет их в массив X.
                                   # Это обычно используется для выделения признаков (фичей) данных (которые будут обрабатыватся в будущем).
y = companies.iloc[:, 4].values  # извлекает все данные из столбца 4 (пятый столбец) и сохраняет их в массив y.
                                 # Это обычно используется для выделения целевой переменной (которую хотим получить в будущем).
companies.head()  # выводит первые пять строк DataFrame companies для просмотра структуры и примера данных.
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
# Data Visualisation
# Building the Correlation matrix
# Выбор только числовых столбцов
# sns.heatmap(companies.corr())

# Выбор только числовых столбцов
numeric_data = companies.select_dtypes(include=[np.number])

# Построение тепловой карты корреляции
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")
plt.show()
